# %% [markdown]
# ## IPL Match Anlaysis

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %% [markdown]
# Load the Data

# %%
df = pd.read_csv('matches.csv')

# %% [markdown]
# Data Exploaation

# %%
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN

# %%
df.shape
# Out:
# (756, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
#  17  umpire3          119 non-null    object
# dtypes: int64(4), object(14)
# memory usage: 106.4+ KB

# %%
df['city'].value_counts()[:5]
# Out:
# Mumbai       101
# Kolkata       77
# Delhi         74
# Bangalore     66
# Hyderabad     64
# Name: city, dtype: int64

# %%
df['Season'].value_counts()
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2010    60
# IPL-2014    60
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2017    59
# IPL-2015    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# **Summarizing interesting facts from the data :**

# %%
print('Total number of Teams :',df['team1'].nunique())
print('Total number of Seasons :',df['Season'].nunique())
print('Total number of Venues :',df['venue'].nunique())
print('Total number of Cities :',df['city'].nunique())
# Out:
# Total number of Teams : 15
# Total number of Seasons : 12
# Total number of Venues : 41
# Total number of Cities : 32

# %%
df['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
df['city'] = df['city'].replace('Bangalore' , 'Bengaluru')

# %%
# Lets find the top 6 cities where maximum matches are played :

print('Top 6 cities where maximun number of matches are played :\n',df['city'].value_counts()[:6])
# Out:
# Top 6 cities where maximun number of matches are played :
#  Mumbai       101
# Bengaluru     80
# Kolkata       77
# Delhi         74
# Hyderabad     64
# Chennai       57
# Name: city, dtype: int64

# %%
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bengaluru  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN

# %%
# Lets check all the umpires who have umpired :
ump_1 = set(df['umpire1'].unique())
ump_2 = set(df['umpire2'].unique())
ump_3 = set(df['umpire3'].unique())

ump = ump_1.intersection(ump_2)
ump = ump.intersection(ump_3)

print('The number of umpires :',len(ump))
print('Names of umpires :',ump)
# Out:
# The number of umpires : 20
# Names of umpires : {'O Nandan', 'Anil Chaudhary', 'K Ananthapadmanabhan', 'Yeshwant Barde', 'Ulhas Gandhe', 'KN Ananthapadmanabhan', 'Vineet Kulkarni', 'Chris Gaffaney', 'Nitin Menon', 'Bruce Oxenford', 'Nigel Llong', 'Kumar Dharmasena', nan, 'Anil Dandekar', 'A Nanda Kishore', 'C Shamshuddin', 'Ian Gould', 'Nanda Kishore', 'Rod Tucker', 'S Ravi'}

# %%
# Lets find out the matches in which there were no umpires at all :

df[(df['umpire1'].isnull()) &
   (df['umpire2'].isnull()) &
   (df['umpire3'].isnull())][['date','team1','team2','winner','umpire1','umpire2','umpire3']]
# Out:
#            date                        team1             team2  \
# 4    08-04-2017  Royal Challengers Bangalore  Delhi Daredevils
# 753  08-05-2019          Sunrisers Hyderabad    Delhi Capitals
#
#                           winner umpire1 umpire2 umpire3
# 4    Royal Challengers Bangalore     NaN     NaN     NaN
# 753               Delhi Capitals     NaN     NaN     NaN

# %%
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bengaluru  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN

# %% [markdown]
# **Exploring the best players from IPL :**

# %%
print('Number of Players who have won the player of the match award :',df['player_of_match'].nunique())

# Lets check the top 10 players winning max. player of the match award :
df['player_of_match'].value_counts()[:10]
# Out:
# Number of Players who have won the player of the match award : 226
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
# Checking the matches where Chris Gayle won the title of “player of the match” :

gayle_playerofmatch = df[df['player_of_match'] == 'CH Gayle'].reset_index(drop = True)
gayle_playerofmatch
# Out:
#        id    Season        city        date                        team1  \
# 0      20  IPL-2017      Rajkot  18-04-2017  Royal Challengers Bangalore
# 1     123  IPL-2009      Durban  21-04-2009              Kings XI Punjab
# 2     258  IPL-2011     Kolkata  22-04-2011        Kolkata Knight Riders
# 3     280  IPL-2011   Bengaluru  06-05-2011  Royal Challengers Bangalore
# 4     283  IPL-2011   Bengaluru  08-05-2011         Kochi Tuskers Kerala
# 5     291  IPL-2011   Bengaluru  14-05-2011        Kolkata Knight Riders
# 6     302  IPL-2011   Bengaluru  22-05-2011          Chennai Super Kings
# 7     306  IPL-2011     Chennai  27-05-2011  Royal Challengers Bangalore
# 8     329  IPL-2012   Bengaluru  17-04-2012                Pune Warriors
# 9     333  IPL-2012  Chandigarh  20-04-2012              Kings XI Punjab
# 10    360  IPL-2012      Mumbai  09-05-2012               Mumbai Indians
# 11    362  IPL-2012        Pune  11-05-2012  Royal Challengers Bangalore
# 12    372  IPL-2012       Delhi  17-05-2012  Royal Challengers Bangalore
# 13    383  IPL-2013   Bengaluru  04-04-2013  Royal Challengers Bangalore
# 14    392  IPL-2013   Bengaluru  11-04-2013        Kolkata Knight Riders
# 15    411  IPL-2013   Bengaluru  23-04-2013  Royal Challengers Bangalore
# 16    522  IPL-2015     Kolkata  11-04-2015        Kolkata Knight Riders
# 17    557  IPL-2015   Bengaluru  06-05-2015  Royal Challengers Bangalore
# 18   7905  IPL-2018      Mohali  15-04-2018              Kings XI Punjab
# 19   7909  IPL-2018      Mohali  19-04-2018              Kings XI Punjab
# 20  11140  IPL-2019      Jaipur  25-03-2019              Kings XI Punjab
#
#                           team2                  toss_winner toss_decision  \
# 0                 Gujarat Lions                Gujarat Lions         field
# 1         Kolkata Knight Riders        Kolkata Knight Riders         field
# 2   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 3               Kings XI Punjab              Kings XI Punjab         field
# 4   Royal Challengers Bangalore         Kochi Tuskers Kerala           bat
# 5   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 6   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 7                Mumbai Indians               Mumbai Indians         field
# 8   Royal Challengers Bangalore                Pune Warriors           bat
# 9   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 10  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 11                Pune Warriors                Pune Warriors         field
# 12             Delhi Daredevils             Delhi Daredevils         field
# 13               Mumbai Indians               Mumbai Indians         field
# 14  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 15                Pune Warriors                Pune Warriors         field
# 16  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 17              Kings XI Punjab              Kings XI Punjab         field
# 18          Chennai Super Kings          Chennai Super Kings         field
# 19          Sunrisers Hyderabad              Kings XI Punjab           bat
# 20             Rajasthan Royals             Rajasthan Royals         field
#
#     result  dl_applied                       winner  win_by_runs  \
# 0   normal           0  Royal Challengers Bangalore           21
# 1   normal           1        Kolkata Knight Riders           11
# 2   normal           0  Royal Challengers Bangalore            0
# 3   normal           0  Royal Challengers Bangalore           85
# 4   normal           0  Royal Challengers Bangalore            0
# 5   normal           1  Royal Challengers Bangalore            0
# 6   normal           0  Royal Challengers Bangalore            0
# 7   normal           0  Royal Challengers Bangalore           43
# 8   normal           0  Royal Challengers Bangalore            0
# 9   normal           0  Royal Challengers Bangalore            0
# 10  normal           0  Royal Challengers Bangalore            0
# 11  normal           0  Royal Challengers Bangalore           35
# 12  normal           0  Royal Challengers Bangalore           21
# 13  normal           0  Royal Challengers Bangalore            2
# 14  normal           0  Royal Challengers Bangalore            0
# 15  normal           0  Royal Challengers Bangalore          130
# 16  normal           0  Royal Challengers Bangalore            0
# 17  normal           0  Royal Challengers Bangalore          138
# 18  normal           0              Kings XI Punjab            4
# 19  normal           0              Kings XI Punjab           15
# 20  normal           0              Kings XI Punjab           14
#
#     win_by_wickets player_of_match  \
# 0                0        CH Gayle
# 1                0        CH Gayle
# 2                9        CH Gayle
# 3                0        CH Gayle
# 4                9        CH Gayle
# 5                4        CH Gayle
# 6                8        CH Gayle
# 7                0        CH Gayle
# 8                6        CH Gayle
# 9                5        CH Gayle
# 10               9        CH Gayle
# 11               0        CH Gayle
# 12               0        CH Gayle
# 13               0        CH Gayle
# 14               8        CH Gayle
# 15               0        CH Gayle
# 16               3        CH Gayle
# 17               0        CH Gayle
# 18               0        CH Gayle
# 19               0        CH Gayle
# 20               0        CH Gayle
#
#                                                 venue          umpire1  \
# 0              Saurashtra Cricket Association Stadium           S Ravi
# 1                                           Kingsmead        DJ Harper
# 2                                        Eden Gardens        SS Hazare
# 3                               M Chinnaswamy Stadium        Aleem Dar
# 4                               M Chinnaswamy Stadium        Aleem Dar
# 5                               M Chinnaswamy Stadium      RE Koertzen
# 6                               M Chinnaswamy Stadium      K Hariharan
# 7                     MA Chidambaram Stadium, Chepauk        Asad Rauf
# 8                               M Chinnaswamy Stadium         S Asnani
# 9          Punjab Cricket Association Stadium, Mohali           S Ravi
# 10                                   Wankhede Stadium        BF Bowden
# 11                         Subrata Roy Sahara Stadium        BF Bowden
# 12                                   Feroz Shah Kotla  HDPK Dharmasena
# 13                              M Chinnaswamy Stadium      VA Kulkarni
# 14                              M Chinnaswamy Stadium        Asad Rauf
# 15                              M Chinnaswamy Stadium        Aleem Dar
# 16                                       Eden Gardens           S Ravi
# 17                              M Chinnaswamy Stadium   RK Illingworth
# 18  Punjab Cricket Association IS Bindra Stadium, ...  Vineet Kulkarni
# 19  Punjab Cricket Association IS Bindra Stadium, ...      Nigel Llong
# 20                             Sawai Mansingh Stadium    C Shamshuddin
#
#                  umpire2          umpire3
# 0              VK Sharma              NaN
# 1              SD Ranade              NaN
# 2              RB Tiffin              NaN
# 3              RB Tiffin              NaN
# 4              SS Hazare              NaN
# 5              RB Tiffin              NaN
# 6            RE Koertzen              NaN
# 7             SJA Taufel              NaN
# 8                  S Das              NaN
# 9              RJ Tucker              NaN
# 10           VA Kulkarni              NaN
# 11           SK Tarapore              NaN
# 12         C Shamshuddin              NaN
# 13         C Shamshuddin              NaN
# 14          AK Chaudhary              NaN
# 15         C Shamshuddin              NaN
# 16         C Shamshuddin              NaN
# 17           VA Kulkarni              NaN
# 18              O Nandan      Nigel Llong
# 19        Anil Chaudhary  Vineet Kulkarni
# 20  KN Anantapadmanabhan   Bruce Oxenford

# %% [markdown]
# 1. Chris Gayle used to play for Royal Challengers Bangalore before 2018 and after 2018, Chris Gayle was bought by Kings XI Punjab in the IPL Auction.
# 2. After 2018, Kings XI Punjab has won the matches where Chris Gayle has shown his excellent performance.

# %% [markdown]
# **Discovering the Biggest Matches in IPL :**

# %%
df[['win_by_runs','win_by_wickets']].describe()
# Out:
#        win_by_runs  win_by_wickets
# count   756.000000      756.000000
# mean     13.283069        3.350529
# std      23.471144        3.387963
# min       0.000000        0.000000
# 25%       0.000000        0.000000
# 50%       0.000000        4.000000
# 75%      19.000000        6.000000
# max     146.000000       10.000000

# %%
# Lets check the biggest win of margin 146 runs :

df[df['win_by_runs'] == 146][['Season','team1','team2','winner','player_of_match','umpire1','umpire2','umpire3']]
# Out:
#       Season           team1             team2          winner  \
# 43  IPL-2017  Mumbai Indians  Delhi Daredevils  Mumbai Indians
#
#    player_of_match      umpire1    umpire2 umpire3
# 43     LMP Simmons  Nitin Menon  CK Nandan     NaN

# %% [markdown]
# **“Mumbai Indians” who has won against “Delhi Daredevils” in IPL-2017 by 146 runs.**

# %%
# Lets check the check the teams winning by 10 wickets :

df[df['win_by_wickets'] == 10][['Season','team1','team2','winner','win_by_wickets','umpire1','umpire2','umpire3']].reset_index(drop = True)
# Out:
#       Season             team1                        team2  \
# 0   IPL-2017     Gujarat Lions        Kolkata Knight Riders
# 1   IPL-2017  Delhi Daredevils              Kings XI Punjab
# 2   IPL-2008    Mumbai Indians              Deccan Chargers
# 3   IPL-2009   Kings XI Punjab             Delhi Daredevils
# 4   IPL-2010  Rajasthan Royals  Royal Challengers Bangalore
# 5   IPL-2011    Mumbai Indians             Rajasthan Royals
# 6   IPL-2012  Rajasthan Royals               Mumbai Indians
# 7   IPL-2013   Kings XI Punjab          Chennai Super Kings
# 8   IPL-2015  Delhi Daredevils  Royal Challengers Bangalore
# 9   IPL-2016     Gujarat Lions          Sunrisers Hyderabad
# 10  IPL-2018   Kings XI Punjab  Royal Challengers Bangalore
#
#                          winner  win_by_wickets          umpire1  \
# 0         Kolkata Knight Riders              10      Nitin Menon
# 1               Kings XI Punjab              10         YC Barde
# 2               Deccan Chargers              10        Asad Rauf
# 3              Delhi Daredevils              10        MR Benson
# 4   Royal Challengers Bangalore              10      K Hariharan
# 5              Rajasthan Royals              10      RE Koertzen
# 6                Mumbai Indians              10  HDPK Dharmasena
# 7           Chennai Super Kings              10        Aleem Dar
# 8   Royal Challengers Bangalore              10        M Erasmus
# 9           Sunrisers Hyderabad              10       K Bharatan
# 10  Royal Challengers Bangalore              10   Bruce Oxenford
#
#                   umpire2   umpire3
# 0               CK Nandan       NaN
# 1               CK Nandan       NaN
# 2              SL Shastri       NaN
# 3               SD Ranade       NaN
# 4               DJ Harper       NaN
# 5              PR Reiffel       NaN
# 6           C Shamshuddin       NaN
# 7           C Shamshuddin       NaN
# 8                  S Ravi       NaN
# 9         HDPK Dharmasena       NaN
# 10  Virender Kumar Sharma  O Nandan

# %% [markdown]
# *   There are 11 teams who won against their competitors by 10 wickets.
# *   Royal Challengers Bangalore did this commendable job not only once but thrice which is quite good

# %%
# Top 10 victory moments for RCB :

win_by_runs = df[(df['winner'] == 'Royal Challengers Bangalore') & (df['win_by_runs'] > 100)]
win_by_wickets = df[(df['winner'] == 'Royal Challengers Bangalore') & (df['win_by_wickets'] > 7)]
win_by_runs = win_by_runs.append(win_by_wickets)

rcb_greatest_victory = win_by_runs.reset_index()[:10]
rcb_greatest_victory
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_9052\2574658393.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   win_by_runs = win_by_runs.append(win_by_wickets)
#    index   id    Season          city        date  \
# 0    410  411  IPL-2013     Bengaluru  23-04-2013
# 1    556  557  IPL-2015     Bengaluru  06-05-2015
# 2    619  620  IPL-2016     Bengaluru  14-05-2016
# 3    142  143  IPL-2009  Johannesburg  03-05-2009
# 4    180  181  IPL-2010     Bengaluru  16-03-2010
# 5    183  184  IPL-2010     Bengaluru  18-03-2010
# 6    232  233  IPL-2010        Mumbai  24-04-2010
# 7    257  258  IPL-2011       Kolkata  22-04-2011
# 8    282  283  IPL-2011     Bengaluru  08-05-2011
# 9    287  288  IPL-2011        Jaipur  11-05-2011
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore                Pune Warriors
# 1  Royal Challengers Bangalore              Kings XI Punjab
# 2  Royal Challengers Bangalore                Gujarat Lions
# 3               Mumbai Indians  Royal Challengers Bangalore
# 4              Kings XI Punjab  Royal Challengers Bangalore
# 5             Rajasthan Royals  Royal Challengers Bangalore
# 6              Deccan Chargers  Royal Challengers Bangalore
# 7        Kolkata Knight Riders  Royal Challengers Bangalore
# 8         Kochi Tuskers Kerala  Royal Challengers Bangalore
# 9             Rajasthan Royals  Royal Challengers Bangalore
#
#                    toss_winner toss_decision  result  dl_applied  \
# 0                Pune Warriors         field  normal           0
# 1              Kings XI Punjab         field  normal           0
# 2                Gujarat Lions         field  normal           0
# 3               Mumbai Indians           bat  normal           0
# 4              Kings XI Punjab           bat  normal           0
# 5  Royal Challengers Bangalore         field  normal           0
# 6              Deccan Chargers           bat  normal           0
# 7  Royal Challengers Bangalore         field  normal           0
# 8         Kochi Tuskers Kerala           bat  normal           0
# 9  Royal Challengers Bangalore         field  normal           0
#
#                         winner  win_by_runs  win_by_wickets player_of_match  \
# 0  Royal Challengers Bangalore          130               0        CH Gayle
# 1  Royal Challengers Bangalore          138               0        CH Gayle
# 2  Royal Challengers Bangalore          144               0  AB de Villiers
# 3  Royal Challengers Bangalore            0               9       JH Kallis
# 4  Royal Challengers Bangalore            0               8       JH Kallis
# 5  Royal Challengers Bangalore            0              10       JH Kallis
# 6  Royal Challengers Bangalore            0               9        A Kumble
# 7  Royal Challengers Bangalore            0               9        CH Gayle
# 8  Royal Challengers Bangalore            0               9        CH Gayle
# 9  Royal Challengers Bangalore            0               9       S Aravind
#
#                         venue          umpire1         umpire2 umpire3
# 0       M Chinnaswamy Stadium        Aleem Dar   C Shamshuddin     NaN
# 1       M Chinnaswamy Stadium   RK Illingworth     VA Kulkarni     NaN
# 2       M Chinnaswamy Stadium      AY Dandekar       VK Sharma     NaN
# 3       New Wanderers Stadium      RE Koertzen  TH Wijewardene     NaN
# 4       M Chinnaswamy Stadium            S Das       DJ Harper     NaN
# 5       M Chinnaswamy Stadium      K Hariharan       DJ Harper     NaN
# 6  Dr DY Patil Sports Academy      RE Koertzen      SJA Taufel     NaN
# 7                Eden Gardens        SS Hazare       RB Tiffin     NaN
# 8       M Chinnaswamy Stadium        Aleem Dar       SS Hazare     NaN
# 9      Sawai Mansingh Stadium  HDPK Dharmasena     K Hariharan     NaN

# %%
# Maximun win by runs margin for Chennai Super Kings :

csk_win_by_runs = df[(df['winner'] == 'Chennai Super Kings') & (df['win_by_runs'] > 50)].reset_index()
csk_win_by_runs
# Out:
#     index     id    Season            city        date                team1  \
# 0     121    122  IPL-2009  Port Elizabeth  20-04-2009  Chennai Super Kings
# 1     143    144  IPL-2009     East London  04-05-2009  Chennai Super Kings
# 2     181    182  IPL-2010         Kolkata  16-03-2010  Chennai Super Kings
# 3     284    285  IPL-2011          Jaipur  09-05-2011  Chennai Super Kings
# 4     306    307  IPL-2011         Chennai  28-05-2011  Chennai Super Kings
# 5     312    313  IPL-2012   Visakhapatnam  07-04-2012  Chennai Super Kings
# 6     379    380  IPL-2012         Chennai  25-05-2012  Chennai Super Kings
# 7     403    404  IPL-2013           Delhi  18-04-2013  Chennai Super Kings
# 8     434    435  IPL-2013       Hyderabad  08-05-2013  Chennai Super Kings
# 9     464    465  IPL-2014       Abu Dhabi  21-04-2014  Chennai Super Kings
# 10    541    542  IPL-2015         Chennai  25-04-2015  Chennai Super Kings
# 11    652   7910  IPL-2018            Pune  20-04-2018  Chennai Super Kings
# 12    745  11341  IPL-2019         Chennai  01-05-2019  Chennai Super Kings
#
#                           team2          toss_winner toss_decision  result  \
# 0   Royal Challengers Bangalore  Chennai Super Kings           bat  normal
# 1               Deccan Chargers  Chennai Super Kings           bat  normal
# 2         Kolkata Knight Riders  Chennai Super Kings           bat  normal
# 3              Rajasthan Royals     Rajasthan Royals         field  normal
# 4   Royal Challengers Bangalore  Chennai Super Kings           bat  normal
# 5               Deccan Chargers      Deccan Chargers         field  normal
# 6              Delhi Daredevils     Delhi Daredevils         field  normal
# 7              Delhi Daredevils  Chennai Super Kings           bat  normal
# 8           Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 9              Delhi Daredevils  Chennai Super Kings           bat  normal
# 10              Kings XI Punjab  Chennai Super Kings           bat  normal
# 11             Rajasthan Royals     Rajasthan Royals         field  normal
# 12               Delhi Capitals       Delhi Capitals         field  normal
#
#     dl_applied               winner  win_by_runs  win_by_wickets  \
# 0            0  Chennai Super Kings           92               0
# 1            0  Chennai Super Kings           78               0
# 2            0  Chennai Super Kings           55               0
# 3            0  Chennai Super Kings           63               0
# 4            0  Chennai Super Kings           58               0
# 5            0  Chennai Super Kings           74               0
# 6            0  Chennai Super Kings           86               0
# 7            0  Chennai Super Kings           86               0
# 8            0  Chennai Super Kings           77               0
# 9            0  Chennai Super Kings           93               0
# 10           0  Chennai Super Kings           97               0
# 11           0  Chennai Super Kings           64               0
# 12           0  Chennai Super Kings           80               0
#
#    player_of_match                                              venue  \
# 0   M Muralitharan                                   St George's Park
# 1         MS Dhoni                                       Buffalo Park
# 2         MS Dhoni                                       Eden Gardens
# 3          M Vijay                             Sawai Mansingh Stadium
# 4          M Vijay                    MA Chidambaram Stadium, Chepauk
# 5        RA Jadeja  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 6          M Vijay                    MA Chidambaram Stadium, Chepauk
# 7       MEK Hussey                                   Feroz Shah Kotla
# 8         SK Raina          Rajiv Gandhi International Stadium, Uppal
# 9         SK Raina                               Sheikh Zayed Stadium
# 10     BB McCullum                    MA Chidambaram Stadium, Chepauk
# 11       SR Watson            Maharashtra Cricket Association Stadium
# 12        MS Dhoni                          M. A. Chidambaram Stadium
#
#             umpire1               umpire2     umpire3
# 0        BG Jerling            SJA Taufel         NaN
# 1       BR Doctrove             M Erasmus         NaN
# 2   HDPK Dharmasena             AM Saheba         NaN
# 3       K Hariharan            SJA Taufel         NaN
# 4         Asad Rauf            SJA Taufel         NaN
# 5         JD Cloete       HDPK Dharmasena         NaN
# 6       BR Doctrove            SJA Taufel         NaN
# 7         M Erasmus           VA Kulkarni         NaN
# 8             S Das              NJ Llong         NaN
# 9    RK Illingworth         C Shamshuddin         NaN
# 10        JD Cloete         C Shamshuddin         NaN
# 11      Nitin Menon  K Ananthapadmanabhan  Rod Tucker
# 12    Anil Dandekar           Nitin Menon   Ian Gould

# %% [markdown]
# Chennai Super Kings have won by a maximum margin of 97 runs.

# %%
# Maximun win by runs margin for Mumbai Indians :

mi_win_by_runs = df[(df['winner'] == 'Mumbai Indians') & (df['win_by_runs'] > 100)]
mi_win_by_runs
# Out:
#        id    Season     city        date           team1  \
# 43     44  IPL-2017    Delhi  06-05-2017  Mumbai Indians
# 676  7934  IPL-2018  Kolkata  09-05-2018  Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# 43        Delhi Daredevils       Delhi Daredevils         field  normal
# 676  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
#
#      dl_applied          winner  win_by_runs  win_by_wickets player_of_match  \
# 43            0  Mumbai Indians          146               0     LMP Simmons
# 676           0  Mumbai Indians          102               0    Ishan Kishan
#
#                 venue         umpire1               umpire2           umpire3
# 43   Feroz Shah Kotla     Nitin Menon             CK Nandan               NaN
# 676      Eden Gardens  Anil Chaudhary  K Ananthapadmanabhan  Kumar Dharmasena

# %% [markdown]
# Mumbai Indians have won by a maximum margin of 146 runs.

# %% [markdown]
# **Understanding the Match Results :**

# %%
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bengaluru  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN

# %%
# Lets see the match results :

df['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
# Lets check the tied matches :
df[df['result'] == 'tie'][['date','team1','team2','venue']].reset_index(drop = True)
# Out:
#          date                        team1                        team2  \
# 0  29-04-2017                Gujarat Lions               Mumbai Indians
# 1  23-04-2009             Rajasthan Royals        Kolkata Knight Riders
# 2  21-03-2010              Kings XI Punjab          Chennai Super Kings
# 3  07-04-2013  Royal Challengers Bangalore          Sunrisers Hyderabad
# 4  16-04-2013             Delhi Daredevils  Royal Challengers Bangalore
# 5  29-04-2014             Rajasthan Royals        Kolkata Knight Riders
# 6  21-04-2015             Rajasthan Royals              Kings XI Punjab
# 7  30-03-2019        Kolkata Knight Riders               Delhi Capitals
# 8  02-05-2019               Mumbai Indians          Sunrisers Hyderabad
#
#                                        venue
# 0     Saurashtra Cricket Association Stadium
# 1                                   Newlands
# 2            MA Chidambaram Stadium, Chepauk
# 3  Rajiv Gandhi International Stadium, Uppal
# 4                      M Chinnaswamy Stadium
# 5                       Sheikh Zayed Stadium
# 6               Sardar Patel Stadium, Motera
# 7                    Feroz Shah Kotla Ground
# 8                           Wankhede Stadium

# %%
# Lets check the no result matches :
df[df['result'] == 'no result'][['date','team1','team2','venue']].reset_index(drop = True)
# Out:
#          date                        team1                        team2  \
# 0  21-05-2011             Delhi Daredevils                Pune Warriors
# 1  29-04-2015  Royal Challengers Bangalore             Rajasthan Royals
# 2  17-05-2015             Delhi Daredevils  Royal Challengers Bangalore
# 3  30-04-2019  Royal Challengers Bangalore             Rajasthan Royals
#
#                     venue
# 0        Feroz Shah Kotla
# 1   M Chinnaswamy Stadium
# 2   M Chinnaswamy Stadium
# 3  M. Chinnaswamy Stadium

# %% [markdown]
# **Uncovering the Most Popular IPL Seasons and Teams :**

# %%
# Lets check the number of IPL Seasons :

plt.figure(figsize = (15,8))
sns.countplot(y = df['Season'].sort_values(),data = df)
plt.show()

# %% [markdown]
# And you can see that IPL-2013 had the maximum number of matches.
# Then IPL-2012 and IPL-2011.
# All other seasons have an almost equal number of matches.

# %%
# Let's check the teams :

plt.figure(figsize = (15,8))
team = df['team1'].append(df['team2'])
sns.countplot( y = team, data = df)
plt.title('Most Matches for IPL teams')
plt.xlabel('Number of matches played')
plt.show()
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_9052\2528258916.py:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team = df['team1'].append(df['team2'])

# %% [markdown]
# Mumbai Indians – They have played the maximum number of matches in all IPL seasons.
# Even Mumbai Indians is the team who has won the IPL trophy four times.

# %% [markdown]
# **Realizing the Locations for all the IPL Seasons :**

# %%
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bengaluru  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN

# %%
# Let's check the venues :

plt.figure(figsize = (15,8))
sns.barplot(y = df['venue'].value_counts().head(15).index,
            x = df['venue'].value_counts().head(15).values,
            palette = 'cool')
plt.title('Most venues for IPL Matches')
plt.xlabel('Number of matches played')
plt.show()

# %% [markdown]
# Eden Gardens is in the top position. Maximum number of IPL matches have been played here. Second, M chinnaswamy stadium.
# Third, Wankhede stadium.

# %%
# Let's check the cities :

plt.figure(figsize = (15,8))
sns.barplot(y = df['city'].value_counts().head(15).index,
            x = df['city'].value_counts().head(15).values,
            palette = 'cool')
plt.title('Most Cities for IPL Matches')
plt.xlabel('Number of matches played')
plt.show()

# %% [markdown]
# Mumbai stands in the top position, followed by Bengaluru and Kolkata.

# %% [markdown]
# **Comparing Toss Winners and Winners :**

# %%
toss_winner_match_winner = df[df['toss_winner'] == df['winner']].reset_index()
toss_winner_match_winner
# Out:
#      index     id    Season           city        date  \
# 0        1      2  IPL-2017           Pune  06-04-2017
# 1        2      3  IPL-2017         Rajkot  07-04-2017
# 2        3      4  IPL-2017         Indore  08-04-2017
# 3        4      5  IPL-2017      Bengaluru  08-04-2017
# 4        5      6  IPL-2017      Hyderabad  09-04-2017
# ..     ...    ...       ...            ...         ...
# 388    750  11346  IPL-2019         Mohali  05-05-2019
# 389    751  11347  IPL-2019         Mumbai  05-05-2019
# 390    753  11413  IPL-2019  Visakhapatnam  08-05-2019
# 391    754  11414  IPL-2019  Visakhapatnam  10-05-2019
# 392    755  11415  IPL-2019      Hyderabad  12-05-2019
#
#                            team1                   team2  \
# 0                 Mumbai Indians  Rising Pune Supergiant
# 1                  Gujarat Lions   Kolkata Knight Riders
# 2         Rising Pune Supergiant         Kings XI Punjab
# 3    Royal Challengers Bangalore        Delhi Daredevils
# 4                  Gujarat Lions     Sunrisers Hyderabad
# ..                           ...                     ...
# 388          Chennai Super Kings         Kings XI Punjab
# 389        Kolkata Knight Riders          Mumbai Indians
# 390          Sunrisers Hyderabad          Delhi Capitals
# 391               Delhi Capitals     Chennai Super Kings
# 392               Mumbai Indians     Chennai Super Kings
#
#                      toss_winner toss_decision  result  dl_applied  \
# 0         Rising Pune Supergiant         field  normal           0
# 1          Kolkata Knight Riders         field  normal           0
# 2                Kings XI Punjab         field  normal           0
# 3    Royal Challengers Bangalore           bat  normal           0
# 4            Sunrisers Hyderabad         field  normal           0
# ..                           ...           ...     ...         ...
# 388              Kings XI Punjab         field  normal           0
# 389               Mumbai Indians         field  normal           0
# 390               Delhi Capitals         field  normal           0
# 391          Chennai Super Kings         field  normal           0
# 392               Mumbai Indians           bat  normal           0
#
#                           winner  win_by_runs  win_by_wickets player_of_match  \
# 0         Rising Pune Supergiant            0               7       SPD Smith
# 1          Kolkata Knight Riders            0              10         CA Lynn
# 2                Kings XI Punjab            0               6      GJ Maxwell
# 3    Royal Challengers Bangalore           15               0       KM Jadhav
# 4            Sunrisers Hyderabad            0               9     Rashid Khan
# ..                           ...          ...             ...             ...
# 388              Kings XI Punjab            0               6        KL Rahul
# 389               Mumbai Indians            0               9       HH Pandya
# 390               Delhi Capitals            0               2         RR Pant
# 391          Chennai Super Kings            0               6    F du Plessis
# 392               Mumbai Indians            1               0       JJ Bumrah
#
#                                          venue                umpire1  \
# 0      Maharashtra Cricket Association Stadium         A Nand Kishore
# 1       Saurashtra Cricket Association Stadium            Nitin Menon
# 2                       Holkar Cricket Stadium           AK Chaudhary
# 3                        M Chinnaswamy Stadium                    NaN
# 4    Rajiv Gandhi International Stadium, Uppal             A Deshmukh
# ..                                         ...                    ...
# 388                          IS Bindra Stadium  KN Ananthapadmanabhan
# 389                           Wankhede Stadium          Nanda Kishore
# 390                           ACA-VDCA Stadium                    NaN
# 391                           ACA-VDCA Stadium          Sundaram Ravi
# 392         Rajiv Gandhi Intl. Cricket Stadium            Nitin Menon
#
#             umpire2                  umpire3
# 0            S Ravi                      NaN
# 1         CK Nandan                      NaN
# 2     C Shamshuddin                      NaN
# 3               NaN                      NaN
# 4          NJ Llong                      NaN
# ..              ...                      ...
# 388   C Shamshuddin           Bruce Oxenford
# 389        O Nandan                   S Ravi
# 390             NaN                      NaN
# 391  Bruce Oxenford  Chettithody Shamshuddin
# 392       Ian Gould              Nigel Llong
#
# [393 rows x 19 columns]

# %%
toss_winner_match_winner['toss_winner'].value_counts()
# Out:
# Chennai Super Kings            57
# Mumbai Indians                 56
# Kolkata Knight Riders          53
# Rajasthan Royals               42
# Royal Challengers Bangalore    41
# Kings XI Punjab                35
# Delhi Daredevils               35
# Sunrisers Hyderabad            23
# Deccan Chargers                19
# Gujarat Lions                  10
# Delhi Capitals                  7
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Pune Warriors                   3
# Rising Pune Supergiants         3
# Name: toss_winner, dtype: int64

# %%
# Let's check the teams winning the toss and also winning the match :

plt.figure(figsize = (15,8))
sns.barplot(y = toss_winner_match_winner['toss_winner'].value_counts().head(10).index,
            x = toss_winner_match_winner['toss_winner'].value_counts().head(10).values,
            palette = 'cool')
plt.title('Teams winning the toss and also winning the match')
plt.xlabel('Number of matches won')
plt.show()

# %% [markdown]
# CSK stands first in winning the toss and also winning the matches.Then, Mumbai Indians and after that Kolkata Knight Riders.

# %% [markdown]
# **Checking the Winning Locations for all the Teams :**

# %%
df.head()

# %%
most_wins = df.groupby(['winner'])['city'].value_counts()
pd.set_option('display.max_rows',None)
most_wins
# Out:
# winner                       city
# Chennai Super Kings          Chennai           40
#                              Mumbai            11
#                              Delhi              6
#                              Pune               6
#                              Bengaluru          5
#                              Kolkata            5
#                              Chandigarh         3
#                              Hyderabad          3
#                              Jaipur             3
#                              Ranchi             3
#                              Centurion          2
#                              Port Elizabeth     2
#                              Visakhapatnam      2
#                              Abu Dhabi          1
#                              Dharamsala         1
#                              Durban             1
#                              East London        1
#                              Johannesburg       1
#                              Kimberley          1
#                              Sharjah            1
# Deccan Chargers              Cuttack            3
#                              Hyderabad          3
#                              Mumbai             3
#                              Cape Town          2
#                              Centurion          2
#                              Chennai            2
#                              Delhi              2
#                              Dharamsala         2
#                              Durban             2
#                              Johannesburg       2
#                              Nagpur             2
#                              Bengaluru          1
#                              Kimberley          1
#                              Kochi              1
#                              Pune               1
# Delhi Capitals               Delhi              4
#                              Bengaluru          1
#                              Hyderabad          1
#                              Jaipur             1
#                              Kolkata            1
#                              Mumbai             1
#                              Visakhapatnam      1
# Delhi Daredevils             Delhi             27
#                              Hyderabad          4
#                              Raipur             4
#                              Bengaluru          3
#                              Durban             3
#                              Mumbai             3
#                              Pune               3
#                              Centurion          2
#                              Chennai            2
#                              Ahmedabad          1
#                              Bloemfontein       1
#                              Cape Town          1
#                              Chandigarh         1
#                              Dharamsala         1
#                              East London        1
#                              Jaipur             1
#                              Johannesburg       1
#                              Kanpur             1
#                              Kochi              1
#                              Kolkata            1
#                              Port Elizabeth     1
#                              Rajkot             1
#                              Sharjah            1
#                              Visakhapatnam      1
# Gujarat Lions                Rajkot             3
#                              Chandigarh         2
#                              Kanpur             2
#                              Kolkata            2
#                              Bengaluru          1
#                              Delhi              1
#                              Mumbai             1
#                              Pune               1
# Kings XI Punjab              Chandigarh        22
#                              Mohali             8
#                              Bengaluru          5
#                              Delhi              5
#                              Dharamsala         5
#                              Mumbai             5
#                              Hyderabad          4
#                              Indore             4
#                              Kolkata            3
#                              Abu Dhabi          2
#                              Chennai            2
#                              Durban             2
#                              Rajkot             2
#                              Sharjah            2
#                              Ahmedabad          1
#                              Bloemfontein       1
#                              Cape Town          1
#                              Cuttack            1
#                              Jaipur             1
#                              Johannesburg       1
#                              Kimberley          1
#                              Port Elizabeth     1
#                              Pune               1
#                              Visakhapatnam      1
# Kochi Tuskers Kerala         Kochi              2
#                              Delhi              1
#                              Indore             1
#                              Kolkata            1
#                              Mumbai             1
# Kolkata Knight Riders        Kolkata           45
#                              Bengaluru          8
#                              Pune               6
#                              Delhi              5
#                              Hyderabad          5
#                              Chandigarh         3
#                              Cuttack            3
#                              Jaipur             3
#                              Mumbai             3
#                              Chennai            2
#                              Durban             2
#                              Abu Dhabi          1
#                              Centurion          1
#                              Indore             1
#                              Mohali             1
#                              Rajkot             1
#                              Ranchi             1
#                              Sharjah            1
# Mumbai Indians               Mumbai            53
#                              Kolkata           10
#                              Bengaluru          9
#                              Hyderabad          7
#                              Chennai            5
#                              Chandigarh         4
#                              Delhi              4
#                              Pune               4
#                              Indore             2
#                              Jaipur             2
#                              Port Elizabeth     2
#                              Visakhapatnam      2
#                              Ahmedabad          1
#                              Cape Town          1
#                              Centurion          1
#                              East London        1
#                              Rajkot             1
# Pune Warriors                Pune               4
#                              Mumbai             3
#                              Chandigarh         1
#                              Chennai            1
#                              Delhi              1
#                              Hyderabad          1
#                              Ranchi             1
# Rajasthan Royals             Jaipur            32
#                              Ahmedabad          7
#                              Mumbai             7
#                              Bengaluru          4
#                              Delhi              4
#                              Abu Dhabi          3
#                              Chandigarh         3
#                              Centurion          2
#                              Durban             2
#                              Hyderabad          2
#                              Kolkata            2
#                              Pune               2
#                              Cape Town          1
#                              Chennai            1
#                              Nagpur             1
#                              Port Elizabeth     1
#                              Visakhapatnam      1
# Rising Pune Supergiant       Pune               5
#                              Mumbai             2
#                              Bengaluru          1
#                              Hyderabad          1
#                              Kolkata            1
# Rising Pune Supergiants      Visakhapatnam      2
#                              Delhi              1
#                              Hyderabad          1
#                              Mumbai             1
# Royal Challengers Bangalore  Bengaluru         37
#                              Delhi              6
#                              Mumbai             5
#                              Kolkata            4
#                              Pune               4
#                              Chandigarh         3
#                              Durban             3
#                              Jaipur             3
#                              Johannesburg       3
#                              Centurion          2
#                              Chennai            2
#                              Hyderabad          2
#                              Ahmedabad          1
#                              Cape Town          1
#                              Indore             1
#                              Kochi              1
#                              Mohali             1
#                              Raipur             1
#                              Rajkot             1
#                              Ranchi             1
#                              Sharjah            1
# Sunrisers Hyderabad          Hyderabad         30
#                              Delhi              6
#                              Chandigarh         4
#                              Visakhapatnam      3
#                              Bengaluru          2
#                              Kolkata            2
#                              Mumbai             2
#                              Ahmedabad          1
#                              Jaipur             1
#                              Kanpur             1
#                              Pune               1
#                              Raipur             1
#                              Rajkot             1
#                              Ranchi             1
# Name: city, dtype: int64

# %% [markdown]
# *   Mumbai Indians has won the maximum number of matches in its home town “Mumbai”.
# *   Kolkata also seems to be a lucky city for Mumbai Indians.
# *   After Mumbai Indians there comes Chennai Super Kings who have won 5 matches in Kolkata.
# *   And after that there are very few wins for other IPL teams in Kolkata city.
# *   Maximum matches won are in Chandigarh.

# %% [markdown]
# **Analyzing Toss Decisions in IPL Matches :**

# %%
df.head()

# %%
# Lets check the toss decisions :

df['toss_decision'].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %% [markdown]
# 1. 463 times the toss winners have chosen to field first.
# 2. 293 times the toss winners have chosen to bat first.
#
# That means the toss decision has some association with the result of the match.

# %%
# Checking the Toss decion of all the matches :

field = df[df['toss_decision'] == 'field']
bat = df[df['toss_decision'] == 'bat']
print('Percentage of matches where toss decision is field :',round(field.shape[0]/df.shape[0],2)*100)
print('Percentage of matches where toss decision is bat :',round(bat.shape[0]/df.shape[0],2)*100)
# Out:
# Percentage of matches where toss decision is field : 61.0
# Percentage of matches where toss decision is bat : 39.0

# %%
# Let's check the teams with most toss wins :

plt.figure(figsize = (15,8))
sns.countplot( y = df['toss_winner'], data = df)
plt.title('Teams with most Toss wins')
plt.show()

# %% [markdown]
# 1. Mumbai Indians is the one who has won the toss maximum number of times.
# 2. Kolkata Knight Riders are in second place.
# 3. Chennai Super Kings is in third place.
# 4. Delhi Daredevils and Rajasthan Royals have won the toss an equal number of times.

# %%
# Lets compare the Toss decisions Season wise :

plt.figure(figsize = (14,8))
sns.countplot( x = df['Season'].sort_values(), data = df,hue = df['toss_decision'],palette = 'Paired')
plt.title('Toss decisions Season wise')
plt.show()

# %% [markdown]
# **Observing the toss decision over different IPL seasons**
# 1. It can observed that after IPL 2014, teams started to field first.
# 2. In IPL-2016, 2017, 2018 and 2019 there is a huge fall.
#
# That means teams were rarely choosing to bat first.

# %% [markdown]
# **DL in IPL Matches :**

# %%
# Let's check the Percentage of Matches where DL is applied :

dl_applied = df[df['dl_applied'] == 1].reset_index()
dl_notapplied = df[df['dl_applied'] == 0].reset_index()

print('Percentage of Matches in which DL is applied :',round(dl_applied.shape[0]/df.shape[0],2)*100)
print('Percentage of Matches in which DL is applied :',round(dl_notapplied.shape[0]/df.shape[0],2)*100)
# Out:
# Percentage of Matches in which DL is applied : 3.0
# Percentage of Matches in which DL is applied : 97.0

# %%
# Lets check the winner of the matches where DL was applied :

dl_applied['winner'].value_counts()
# Out:
# Kolkata Knight Riders          4
# Royal Challengers Bangalore    3
# Kings XI Punjab                2
# Chennai Super Kings            2
# Delhi Daredevils               2
# Sunrisers Hyderabad            2
# Rising Pune Supergiants        2
# Kochi Tuskers Kerala           1
# Rajasthan Royals               1
# Name: winner, dtype: int64

# %% [markdown]
# **Key insights from the Project :**
#
# 1. Unique number of teams playing in the IPL.
# 2. Cities where IPL matches have been played.
# 3. Best players of the IPL.
# 4. Performance of the team they were playing for.
# 5. Biggest matches of the IPL.
# 6. Teams won by the maximum number of runs.
# 7. Maximum number of wickets.
# 8. Locations of the matches.
# 9. Teams won the maximum number of matches in their home city.
# 10. Also observed that the toss decisions have some effect with the match winning.
# 11. And at last learned about DL.
